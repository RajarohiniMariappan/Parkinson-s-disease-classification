# %% [markdown]
# # Load the dataset

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read the dataset
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/S7 PROJECT/voice_features.csv')
print(df.head())
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1   spread2  \
# 0      0.06545  0.02211  21.033  0.414783  0.815285 -4.813031  0.266482
# 1      0.09403  0.01929  19.085  0.458359  0.819521 -4.075192  0.335590
# 2      0.08270  0.01309  20.651  0.429895  0.825288 -4.443179  0.311173
# 3      0.08771  0.01353  20.644  0.434969  0.819235 -4.117501  0.334147
# 4      0.10470  0.01767  19.649  0.417356  0.823484 -3.747787  0.234513
#
#          D2       PPE  class
# 0  2.301442  0.284654      1
# 1  2.486855  0.368674      1
# 2  2.342259  0.332634      1
# 3  2.405554  0.368975      1
# 4  2.332180  0.410335      1
#
# [5 rows x 23 columns]

# %% [markdown]
# #Properties of dataset

# %%
#dataset properties
print(df.shape)
# Out:
# (195, 23)

# %%
#dataset properties
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       195 non-null    float64
#  1   MDVP:Fhi(Hz)      195 non-null    float64
#  2   MDVP:Flo(Hz)      195 non-null    float64
#  3   MDVP:Jitter(%)    195 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      195 non-null    float64
#  12  MDVP:APQ          195 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
#  15  HNR               195 non-null    float64
#  16  RPDE              195 non-null    float64
#  17  DFA               195 non-null    float64
#  18  spread1           195 non-null    float64
#  19  spread2           195 non-null    float64
#  20  D2                195 non-null    float64
#  21  PPE               195 non-null    float64
#  22  class             195 non-null    int64
# dtypes: float64(22), int64(1)
# memory usage: 35.2 KB
# None

# %%
#dataset properties
print(df.describe())
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR        RPDE  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.498536
# std            0.194877  ...     0.030459    0.040418    4.425764    0.103942
# min            0.085000  ...     0.013640    0.000650    8.441000    0.256570
# 25%            0.148500  ...     0.024735    0.005925   19.198000    0.421306
# 50%            0.221000  ...     0.038360    0.011660   22.085000    0.495954
# 75%            0.350000  ...     0.060795    0.025640   25.075500    0.587562
# max            1.302000  ...     0.169420    0.314820   33.047000    0.685151
#
#               DFA     spread1     spread2          D2         PPE       class
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.718099   -5.684397    0.226510    2.381826    0.206552    0.753846
# std      0.055336    1.090208    0.083406    0.382799    0.090119    0.431878
# min      0.574282   -7.964984    0.006274    1.423287    0.044539    0.000000
# 25%      0.674758   -6.450096    0.174351    2.099125    0.137451    1.000000
# 50%      0.722254   -5.720868    0.218885    2.361532    0.194052    1.000000
# 75%      0.761881   -5.046192    0.279234    2.636456    0.252980    1.000000
# max      0.825288   -2.434031    0.450493    3.671155    0.527367    1.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# #**Without Pre-processing data, model construction**

# %% [markdown]
# #Min and Max values in dataset

# %%
# Find min and max values
min_values = df.min()
max_values = df.max()

print("Minimum values:\n", min_values)
print("\nMaximum values:\n", max_values)
# Out:
# Minimum values:
#  MDVP:Fo(Hz)          88.333000
# MDVP:Fhi(Hz)        102.145000
# MDVP:Flo(Hz)         65.476000
# MDVP:Jitter(%)        0.001680
# MDVP:Jitter(Abs)      0.000007
# MDVP:RAP              0.000680
# MDVP:PPQ              0.000920
# Jitter:DDP            0.002040
# MDVP:Shimmer          0.009540
# MDVP:Shimmer(dB)      0.085000
# Shimmer:APQ3          0.004550
# Shimmer:APQ5          0.005700
# MDVP:APQ              0.007190
# Shimmer:DDA           0.013640
# NHR                   0.000650
# HNR                   8.441000
# RPDE                  0.256570
# DFA                   0.574282
# spread1              -7.964984
# spread2               0.006274
# D2                    1.423287
# PPE                   0.044539
# class                 0.000000
# dtype: float64
#
# Maximum values:
#  MDVP:Fo(Hz)         260.105000
# MDVP:Fhi(Hz)        592.030000
# MDVP:Flo(Hz)        239.170000
# MDVP:Jitter(%)        0.033160
# MDVP:Jitter(Abs)      0.000260
# MDVP:RAP              0.021440
# MDVP:PPQ              0.019580
# Jitter:DDP            0.064330
# MDVP:Shimmer          0.119080
# MDVP:Shimmer(dB)      1.302000
# Shimmer:APQ3          0.056470
# Shimmer:APQ5          0.079400
# MDVP:APQ              0.137780
# Shimmer:DDA           0.169420
# NHR                   0.314820
# HNR                  33.047000
# RPDE                  0.685151
# DFA                   0.825288
# spread1              -2.434031
# spread2               0.450493
# D2                    3.671155
# PPE                   0.527367
# class                 1.000000
# dtype: float64

# %%
# Find the minimum and maximum values in the entire dataset
minimum = df.min().min()
maximum = df.max().max()

print("Minimum value in the dataset:", minimum)
print("Maximum value in the dataset:", maximum)
# Out:
# Minimum value in the dataset: -7.964984
# Maximum value in the dataset: 592.03

# %% [markdown]
# #Splitting of features and target variable

# %%
# Separate features and target variable
x = df.drop('class', axis=1)
Y = df['class']

# %% [markdown]
# #Target variable

# %%
#count of categerical value in class label
class_counts = Y.value_counts()
print(class_counts)
# Out:
# class
# 1    147
# 0     48
# Name: count, dtype: int64

# %% [markdown]
# #Visualization

# %%
#pie chart to visualize
import matplotlib.pyplot as plt

# Create a pie chart
labels = [1,0]
sizes = [Y.value_counts()[1],Y.value_counts()[0]]

# Define a custom autopct function
def absolute_value(val):
    total = sum(sizes)
    absolute = int(round(val/100.*total))
    return f'{absolute}'

# Create a pie chart
plt.pie(sizes, labels=labels, autopct=absolute_value,startangle=90)

plt.title('Distribution of Classes')
plt.show()

# %% [markdown]
# #Training and testing dataset splitting

# %%
#split the dataset into training and testing
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
x_train, x_test, Y_train, Y_test = train_test_split(x, Y, test_size=0.3, random_state=42)

# Print the shapes of the resulting sets
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# x_train shape: (136, 22)
# x_test shape: (59, 22)
# Y_train shape: (136,)
# Y_test shape: (59,)

# %% [markdown]
# #Construct the CNN model

# %%
#construct 1d cnn model

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# Define the 1D CNN model
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 20, 32)              │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 10, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 8, 64)               │           6,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 4, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 2, 128)              │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 47,681 (186.25 KB)
#  Trainable params: 47,681 (186.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Training the model

# %%
# train the model

# Reshape the input data for the 1D CNN
x_train_reshaped = x_train.values.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test_reshaped = x_test.values.reshape(x_test.shape[0], x_test.shape[1], 1)

# Train the model
history = model.fit(x_train_reshaped, Y_train, epochs=10, batch_size=8, validation_data=(x_test_reshaped, Y_test))
# Out:
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7020 - loss: 0.8903 - val_accuracy: 0.2542 - val_loss: 1.0258
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6405 - loss: 1.0396 - val_accuracy: 0.6949 - val_loss: 0.6466
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7142 - loss: 0.7199 - val_accuracy: 0.7458 - val_loss: 0.6302
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7405 - loss: 0.7531 - val_accuracy: 0.7458 - val_loss: 0.6185
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7535 - loss: 0.5598 - val_accuracy: 0.7288 - val_loss: 0.6438
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6679 - loss: 0.7028 - val_accuracy: 0.7458 - val_loss: 0.6048
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7493 - loss: 0.6540 - val_accuracy: 0.7458 - val_loss: 0.5897
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8091 - loss: 0.5003 - val_accuracy: 0.6780 - val_loss: 0.6641
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6246 - loss: 0.7704 - val_accuracy: 0.7458 - val_loss: 0.5769
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7436 - loss: 0.6447 - val_accuracy: 0.7458 - val_loss: 0.5846

# %% [markdown]
# #Accuracy and Loss curve

# %%
#generate accuracy and loss curve

import matplotlib.pyplot as plt
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# #Calculation of metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, cohen_kappa_score

# Predict on the test set
Y_pred = model.predict(x_test_reshaped)
Y_pred_binary = (Y_pred > 0.5).astype(int)  # Convert probabilities to binary predictions

# Calculate metrics
accuracy = accuracy_score(Y_test, Y_pred_binary)
precision = precision_score(Y_test, Y_pred_binary)
recall = recall_score(Y_test, Y_pred_binary)
f1 = f1_score(Y_test, Y_pred_binary)
kappa = cohen_kappa_score(Y_test, Y_pred_binary)

# Calculate specificity
tn, fp, fn, tp = confusion_matrix(Y_test, Y_pred_binary).ravel()
specificity = tn / (tn + fp)

# Print the metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("Specificity:", specificity)
print("F1 Score:", f1)
print("Kappa Constant:", kappa)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Accuracy: 0.7457627118644068
# Precision: 0.7457627118644068
# Recall: 1.0
# Specificity: 0.0
# F1 Score: 0.8543689320388349
# Kappa Constant: 0.0

# %% [markdown]
# #ROC curve

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities for the positive class
Y_pred_proba = model.predict(x_test_reshaped)[:, 0]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_proba)

# Calculate AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# #**Pre-processed data model construction**

# %% [markdown]
# #Splitting the dataset into features and target

# %%
# Separate features and target variable
X = df.drop('class', axis=1)
y = df['class']

# %% [markdown]
# #Normalizing the features and target variables

# %%
#normalize the values in X using z-score
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the features and transform them
X_normalized = scaler.fit_transform(X)

# Convert the normalized array back to a DataFrame (optional)
X = pd.DataFrame(X_normalized, columns=X.columns)

print(X.head())
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0    -0.829300     -0.436165     -0.952037        0.334914          0.749759
# 1    -0.770972     -0.530974     -0.057721        0.715418          1.037674
# 2    -0.909476     -0.723168     -0.109875        0.884991          1.325589
# 3    -0.909622     -0.649092     -0.114229        0.775389          1.325589
# 4    -0.925657     -0.606245     -0.130608        1.368893          1.901418
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0  0.132963  0.760800    0.131755      0.745985          0.739536  ...
# 1  0.453892  1.276809    0.452684      1.681731          1.768464  ...
# 2  0.720770  1.585687    0.721813      1.202693          1.027636  ...
# 3  0.578885  1.284076    0.577677      1.340396          1.207698  ...
# 4  1.095750  2.047187    1.096793      1.836448          1.552389  ...
#
#    MDVP:APQ  Shimmer:DDA       NHR       HNR      RPDE       DFA   spread1  \
# 0  0.332985     0.607532 -0.067893 -0.193225 -0.807838  1.760814  0.801323
# 1  1.159454     1.548254 -0.137843 -0.634508 -0.387524  1.837562  1.479853
# 2  0.699187     1.175323 -0.291633 -0.279760 -0.662075  1.942048  1.141445
# 3  0.806859     1.340229 -0.280719 -0.281346 -0.613134  1.832380  1.440945
# 4  1.216839     1.899461 -0.178026 -0.506745 -0.783021  1.909364  1.780940
#
#     spread2        D2       PPE
# 0  0.480477 -0.210531  0.868886
# 1  1.311185  0.275077  1.803605
# 2  1.017682 -0.103629  1.402661
# 3  1.293840  0.062145  1.806954
# 4  0.096195 -0.130026  2.267082
#
# [5 rows x 22 columns]

# %% [markdown]
# #Checking the range of values

# %%
# Find the maximum and minimum values in the entire dataset
maximum = X.max().max()
minimum = X.min().min()

print("Maximum value in the normalized dataset:", maximum)
print("Minimum value in the normalized dataset:", minimum)
# Out:
# Maximum value in the normalized dataset: 7.192738112120731
# Minimum value in the normalized dataset: -3.0457071356137835

# %% [markdown]
# #Balancing the target values

# %%
#balance the values in y using smot

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE
# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to balance the dataset
X, y = smote.fit_resample(X, y)
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.6.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.5.0)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %%
#count of categerical value in class label
class_counts = y.value_counts()
print(class_counts)
# Out:
# class
# 1    147
# 0    147
# Name: count, dtype: int64

# %%
#dataset properties
print(X.shape)
# Out:
# (294, 22)

# %% [markdown]
# #Visualization

# %%
#pie chart to visualize
import matplotlib.pyplot as plt

# Create a pie chart
labels = [1,0]
sizes = [y.value_counts()[1],y.value_counts()[0]]

# Define a custom autopct function
def absolute_value(val):
    total = sum(sizes)
    absolute = int(round(val/100.*total))
    return f'{absolute}'

# Create a pie chart
plt.pie(sizes, labels=labels, autopct=absolute_value,startangle=90)

plt.title('Distribution of Classes')
plt.show()

# %% [markdown]
# #Training and testing dataset split

# %%
#split the dataset into training and testing
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shapes of the resulting sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (205, 22)
# X_test shape: (89, 22)
# y_train shape: (205,)
# y_test shape: (89,)

# %% [markdown]
# #Construct the CNN model

# %%
#construct 1d cnn model

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# Define the 1D CNN model
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)                    │ (None, 20, 32)              │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_3 (MaxPooling1D)       │ (None, 10, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_4 (Conv1D)                    │ (None, 8, 64)               │           6,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_4 (MaxPooling1D)       │ (None, 4, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_5 (Conv1D)                    │ (None, 2, 128)              │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_5 (MaxPooling1D)       │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 47,681 (186.25 KB)
#  Trainable params: 47,681 (186.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Training the model

# %%
# train the model

# Reshape the input data for the 1D CNN
X_train_reshaped = X_train.values.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_reshaped = X_test.values.reshape(X_test.shape[0], X_test.shape[1], 1)

# Train the model
history = model.fit(X_train_reshaped, y_train, epochs=25, batch_size=32, validation_data=(X_test_reshaped, y_test))
# Out:
# Epoch 1/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9823 - loss: 0.0462 - val_accuracy: 0.9551 - val_loss: 0.0999
# Epoch 2/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9973 - loss: 0.0179 - val_accuracy: 0.9551 - val_loss: 0.0683
# Epoch 3/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9843 - loss: 0.0409 - val_accuracy: 0.9663 - val_loss: 0.0618
# Epoch 4/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9927 - loss: 0.0308 - val_accuracy: 0.9551 - val_loss: 0.1157
# Epoch 5/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9856 - loss: 0.0275 - val_accuracy: 0.9551 - val_loss: 0.1099
# Epoch 6/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9981 - loss: 0.0178 - val_accuracy: 0.9551 - val_loss: 0.0915
# Epoch 7/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9951 - loss: 0.0227 - val_accuracy: 0.9551 - val_loss: 0.0857
# Epoch 8/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9551 - val_loss: 0.0984
# Epoch 9/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9963 - loss: 0.0123 - val_accuracy: 0.9438 - val_loss: 0.1188
# Epoch 10/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9551 - val_loss: 0.0935
# Epoch 11/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9326 - val_loss: 0.1344
# Epoch 12/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9876 - loss: 0.0245 - val_accuracy: 0.9326 - val_loss: 0.1483
# Epoch 13/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9931 - loss: 0.0291 - val_accuracy: 0.9663 - val_loss: 0.0571
# Epoch 14/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9873 - loss: 0.0267 - val_accuracy: 0.9775 - val_loss: 0.0822
# Epoch 15/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9931 - loss: 0.0161 - val_accuracy: 0.9775 - val_loss: 0.0693
# Epoch 16/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9901 - loss: 0.0210 - val_accuracy: 0.9775 - val_loss: 0.0675
# Epoch 17/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9964 - loss: 0.0131 - val_accuracy: 0.9663 - val_loss: 0.0642
# Epoch 18/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9663 - val_loss: 0.0734
# Epoch 19/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0195 - val_accuracy: 0.9438 - val_loss: 0.1268
# Epoch 20/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0149 - val_accuracy: 0.9326 - val_loss: 0.1540
# Epoch 21/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9551 - val_loss: 0.1238
# Epoch 22/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9551 - val_loss: 0.1096
# Epoch 23/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9964 - loss: 0.0146 - val_accuracy: 0.9326 - val_loss: 0.1421
# Epoch 24/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9892 - loss: 0.0168 - val_accuracy: 0.9213 - val_loss: 0.1474
# Epoch 25/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9964 - loss: 0.0105 - val_accuracy: 0.9663 - val_loss: 0.0945

# %% [markdown]
# #Accuracy and Loss curve

# %%
#generate accuracy and loss curve

import matplotlib.pyplot as plt
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# #Calculation of metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, cohen_kappa_score

# Predict on the test set
y_pred = model.predict(X_test_reshaped)
y_pred_binary = (y_pred > 0.5).astype(int)  # Convert probabilities to binary predictions

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
recall = recall_score(y_test, y_pred_binary)
f1 = f1_score(y_test, y_pred_binary)
kappa = cohen_kappa_score(y_test, y_pred_binary)

# Calculate specificity
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_binary).ravel()
specificity = tn / (tn + fp)

# Print the metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("Specificity:", specificity)
print("F1 Score:", f1)
print("Kappa Constant:", kappa)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy: 0.9662921348314607
# Precision: 0.9795918367346939
# Recall: 0.96
# Specificity: 0.9743589743589743
# F1 Score: 0.9696969696969697
# Kappa Constant: 0.9317310150856558

# %% [markdown]
# #ROC curve

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = model.predict(X_test_reshaped)[:, 0]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calculate AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# # **User Input**

# %%
feature_ranges = df.drop('class', axis=1).agg(['min', 'max'])

# Create input fields for each feature
feature_inputs = {}
for feature in df.columns[:-1]:
  min_val = feature_ranges.loc['min', feature]
  max_val = feature_ranges.loc['max', feature]
  feature_inputs[feature] = float(input(f"Enter value for {feature} (between {min_val} and {max_val}): "))

# Convert the inputs to DataFrame
user_input_df = pd.DataFrame([feature_inputs])
# Out:
# Enter value for MDVP:Fo(Hz) (between 88.333 and 260.105): 100.65
# Enter value for MDVP:Fhi(Hz) (between 102.145 and 592.03): 409.32
# Enter value for MDVP:Flo(Hz) (between 65.476 and 239.17): 65.99
# Enter value for MDVP:Jitter(%) (between 0.00168 and 0.03316): 0.00278
# Enter value for MDVP:Jitter(Abs) (between 7e-06 and 0.00026): 0.00016
# Enter value for MDVP:RAP (between 0.00068 and 0.02144): 0.00078
# Enter value for MDVP:PPQ (between 0.00092 and 0.01958): 0.0013
# Enter value for Jitter:DDP (between 0.00204 and 0.06433): 0.012
# Enter value for MDVP:Shimmer (between 0.00954 and 0.11908): 0.0185
# Enter value for MDVP:Shimmer(dB) (between 0.085 and 1.302): 0.095
# Enter value for Shimmer:APQ3 (between 0.00455 and 0.05647): 0.0345
# Enter value for Shimmer:APQ5 (between 0.0057 and 0.0794): 0.052
# Enter value for MDVP:APQ (between 0.00719 and 0.13778): 0.00815
# Enter value for Shimmer:DDA (between 0.01364 and 0.16942): 0.0234
# Enter value for NHR (between 0.00065 and 0.31482): 0.0145
# Enter value for HNR (between 8.441 and 33.047): 10.012
# Enter value for RPDE (between 0.25657 and 0.685151): 0.345
# Enter value for DFA (between 0.574282 and 0.825288): 0.5890
# Enter value for spread1 (between -7.964984 and -2.434031): -6.8904
# Enter value for spread2 (between 0.006274 and 0.450493): 0.008965
# Enter value for D2 (between 1.423287 and 3.671155): 1.564
# Enter value for PPE (between 0.044539 and 0.527367): 0.03456

# %%
# Normalize the user input
user_input_normalized = scaler.transform(user_input_df)

# Convert the normalized array back to a DataFrame
user_input_df_normalized = pd.DataFrame(user_input_normalized, columns=user_input_df.columns)

# %%
#find the class label for the normalized input using 1d-cnn

# Reshape the user input for the 1D CNN
user_input_reshaped = user_input_df_normalized.values.reshape(user_input_df_normalized.shape[0], user_input_df_normalized.shape[1], 1)

# Predict the class label
predicted_probability = model.predict(user_input_reshaped)[0][0]

# Convert probability to class label (0 or 1)
predicted_class = 1 if predicted_probability > 0.5 else 0

print("Predicted Class Label:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted Class Label: 1
